# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("https://pythonizing.github.io/data/real-estate/rock-springs-wy/LCWYROCKSPRINGS/")
c = r.content

soup = BeautifulSoup(c, "html.parser")

all = soup.find_all("div", {"class":"propertyRow"})

page_number = soup.find_all("a", {"class":"Page"})[-1].text

# %%
l = []
for page in range(0, int(page_number)*10, 10):
    r = requests.get("https://pythonizing.github.io/data/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=" + str(page))
    # c = r.json()["list"]
    soup = BeautifulSoup(c, "html.parser")
    all = soup.find_all("div", {"class":"propertyRow"})
    for item in all:
        d = {}
        d["Address"] = item.find("h4", {"class":"propPrice"}).text.replace("\n", "").replace(" ", "")
        d["Locality"] = item.find_all("span", {"class":"propAddressCollapse"})[0].text
        d["Price"] = item.find_all("span", {"class":"propAddressCollapse"})[1].text
        try:
            d["Area"] = item.find("span", {"class":"infoBed"}).find("b").text
        except:
            d["Area"] = None
            
        try:
            d["Full Baths"] = item.find("span", {"class":"infoValueFullBath"}).find("b").text
        except:
            d["Full Baths"] =None
            
        try:
            d["Half Baths"] =item.find("span", {"class":"infoValueHalfBath"}).find("b").text
        except:
            d["Half Baths"] = None
    
        for column_group in item.find_all("div", {"class":"columnGroup"}):
            for feature_group, feature_name in zip(column_group.find_all("span", {"class":"featureGroup"}),
                                                   column_group.find_all("span", {"class":"featureName"})):
                if "Lot Size" in feature_group.text:
                    d["Lot Size"] = feature_name.text
        l.append(d)

# %%
import pandas
df = pandas.DataFrame(l)

# %%
df
# Out:
#      Address               Locality                   Price  Area Full Baths  \
# 0   $725,000              0 Gateway  Rock Springs, WY 82901  None       None
# 1   $452,900  1003 Winchester Blvd.  Rock Springs, WY 82901     4          4
# 2   $396,900          600 Talladega  Rock Springs, WY 82901     5          3
# 3   $389,900     3239 Spearhead Way  Rock Springs, WY 82901     4          3
# 4   $254,000     522 Emerald Street  Rock Springs, WY 82901     3          3
# 5   $252,900   1302 Veteran's Drive  Rock Springs, WY 82901     4          2
# 6   $210,000       1021 Cypress Cir  Rock Springs, WY 82901     4          3
# 7   $209,000         913 Madison Dr  Rock Springs, WY 82901     3          2
# 8   $199,900      1344 Teton Street  Rock Springs, WY 82901     3          2
# 9   $196,900         4 Minnies Lane  Rock Springs, WY 82901     3          2
# 10  $725,000              0 Gateway  Rock Springs, WY 82901  None       None
# 11  $452,900  1003 Winchester Blvd.  Rock Springs, WY 82901     4          4
# 12  $396,900          600 Talladega  Rock Springs, WY 82901     5          3
# 13  $389,900     3239 Spearhead Way  Rock Springs, WY 82901     4          3
# 14  $254,000     522 Emerald Street  Rock Springs, WY 82901     3          3
# 15  $252,900   1302 Veteran's Drive  Rock Springs, WY 82901     4          2
# 16  $210,000       1021 Cypress Cir  Rock Springs, WY 82901     4          3
# 17  $209,000         913 Madison Dr  Rock Springs, WY 82901     3          2
# 18  $199,900      1344 Teton Street  Rock Springs, WY 82901     3          2
# 19  $196,900         4 Minnies Lane  Rock Springs, WY 82901     3          2
# 20  $725,000              0 Gateway  Rock Springs, WY 82901  None       None
# 21  $452,900  1003 Winchester Blvd.  Rock Springs, WY 82901     4          4
# 22  $396,900          600 Talladega  Rock Springs, WY 82901     5          3
# 23  $389,900     3239 Spearhead Way  Rock Springs, WY 82901     4          3
# 24  $254,000     522 Emerald Street  Rock Springs, WY 82901     3          3
# 25  $252,900   1302 Veteran's Drive  Rock Springs, WY 82901     4          2
# 26  $210,000       1021 Cypress Cir  Rock Springs, WY 82901     4          3
# 27  $209,000         913 Madison Dr  Rock Springs, WY 82901     3          2
# 28  $199,900      1344 Teton Street  Rock Springs, WY 82901     3          2
# 29  $196,900         4 Minnies Lane  Rock Springs, WY 82901     3          2
#
#    Half Baths          Lot Size
# 0        None               NaN
# 1        None        0.21 Acres
# 2        None               NaN
# 3           1  Under 1/2 Acre,
# 4        None  Under 1/2 Acre,
# 5        None        0.27 Acres
# 6        None  Under 1/2 Acre,
# 7        None  Under 1/2 Acre,
# 8        None  Under 1/2 Acre,
# 9        None        2.02 Acres
# 10       None               NaN
# 11       None        0.21 Acres
# 12       None               NaN
# 13          1  Under 1/2 Acre,
# 14       None  Under 1/2 Acre,
# 15       None        0.27 Acres
# 16       None  Under 1/2 Acre,
# 17       None  Under 1/2 Acre,
# 18       None  Under 1/2 Acre,
# 19       None        2.02 Acres
# 20       None               NaN
# 21       None        0.21 Acres
# 22       None               NaN
# 23          1  Under 1/2 Acre,
# 24       None  Under 1/2 Acre,
# 25       None        0.27 Acres
# 26       None  Under 1/2 Acre,
# 27       None  Under 1/2 Acre,
# 28       None  Under 1/2 Acre,
# 29       None        2.02 Acres

# %%
df.to_csv("Output.csv")
